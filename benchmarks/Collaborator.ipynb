# %%
import pandas as pd
import os
import sys

# %%
PATH_TO_PROJECT = os.path.abspath("../")

sys.path.append(PATH_TO_PROJECT)
from recomendator import Ranginator

# %%
PATH_TO_DATASET= os.path.join(PATH_TO_PROJECT, 'datasets/ml-latest-small/ratings.csv')

df = pd.read_csv(PATH_TO_DATASET)

# %%
df
# Out:
#         userId  movieId  rating   timestamp
# 0            1        1     4.0   964982703
# 1            1        3     4.0   964981247
# 2            1        6     4.0   964982224
# 3            1       47     5.0   964983815
# 4            1       50     5.0   964982931
# 5            1       70     3.0   964982400
# 6            1      101     5.0   964980868
# 7            1      110     4.0   964982176
# 8            1      151     5.0   964984041
# 9            1      157     5.0   964984100
# 10           1      163     5.0   964983650
# 11           1      216     5.0   964981208
# 12           1      223     3.0   964980985
# 13           1      231     5.0   964981179
# 14           1      235     4.0   964980908
# 15           1      260     5.0   964981680
# 16           1      296     3.0   964982967
# 17           1      316     3.0   964982310
# 18           1      333     5.0   964981179
# 19           1      349     4.0   964982563
# ...

# %%
ranginator = Ranginator()

# %%
ranginator.fit(df["userId"], df["movieId"], df["rating"])

# %%
ranginator.predict([1])
# Out:
# [[(1.0, 291),
#   (1.0, 253),
#   (1.0, 85),
#   (1.0, 77),
#   (1.0, 1),
#   (0.8, 550),
#   (0.8, 511),
#   (0.8, 472),
#   (0.8, 278),
#   (0.6666666666666666, 366)]]
